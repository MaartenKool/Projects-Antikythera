# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Scalable-Swiss-Clock" data-toc-modified-id="Scalable-Swiss-Clock-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Scalable Swiss Clock</a></span></li><li><span><a href="#Saros-Dial-for-3D-printed-Antikythera-Mechanism" data-toc-modified-id="Saros-Dial-for-3D-printed-Antikythera-Mechanism-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Saros Dial for 3D printed Antikythera Mechanism</a></span></li></ul></div>

# %% [markdown]
# ## Scalable Swiss Clock
#
# The hour hand moves at the rate of 0.5 degrees per minute
# The minute and second hands moves at the rate of of 6 degrees per minute

# %%
#Function to calculate the coordinates when a clock hand rotates
import math

def rotate(origin, point, angle):
    """
    Rotate a point counterclockwise by a given angle around a given origin.

    The angle should be given in radians.
    """
    ox, oy = origin
    px, py = point

    qx = ox + math.cos(angle) * (px - ox) - math.sin(angle) * (py - oy)
    qy = oy + math.sin(angle) * (px - ox) + math.cos(angle) * (py - oy)
    return qx, qy

# %% [markdown]
# ## Saros Dial for 3D printed Antikythera Mechanism
#
# The dial needs to be 7 cm on the horizontal diameter.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# This example fits a4 paper with 4.2 mm margin printers (HP Laserjet Pro 200)

# # figure settings
# figure_width = 20 # cm
# figure_height = 28.7 # cm
# left_right_margin = 1 # cm
# top_bottom_margin = 1 # cm

# # Don't change
# left   = left_right_margin / figure_width # Percentage from height
# bottom = top_bottom_margin / figure_height # Percentage from height
# width  = 1 - left*2
# height = 1 - bottom*2
# cm2inch = 1/2.54 # inch per cm

# # specifying the width and the height of the box in inches
# fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
# ax = fig.add_axes((left, bottom, width, height))

# # limits settings (important)
# # plt.xlim(0, figure_width * width)#(0,0) at left bottom
# # plt.ylim(0, figure_height * height)#(0,0) at left bottom
# plt.xlim(-figure_width * width/2, figure_width * width/2) #centers (0,0)
# plt.ylim(-figure_height * height/2, figure_height * height/2)#centers (0,0)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)



# your Plot (consider above limits)
# # define parameters
a = .03538 # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = 26*np.pi, 34*np.pi # Dial starts at the 13th turn and finishes at the 17th turn
steps = 223+1 # Number of Saros periods (+1 for end marker)


# Generate plotting values
# Main spiral

theta = np.linspace(thetaMin, thetaMax, steps)

r = theta * a

x = r*np.cos(theta)
y = r*np.sin(-theta)

# Main spiral outer rim completion
thetaMinComp, thetaMaxComp = thetaMax, thetaMax+(2*np.pi)

thetaComp= np.linspace(thetaMinComp, thetaMaxComp,steps)


rComp = thetaComp * a

xComp = rComp*np.cos(thetaComp)
yComp = rComp*np.sin(-thetaComp)

# Seperator lines 
# Need to plot between the period startpoint accros the turn(out from the center (0,0))
l=np.sqrt(np.square(x)+np.square(y)+1.2) # calculate length from center, just shortening it makes it not overshoot
xnew= x*1/l*(l+2*np.pi*a) # get the x  for the line extendeaccros the turn
ynew= y*1/l*(l+2*np.pi*a) # get the y  for the line extendeaccros the turn


for i in range(len(x)):
    plt.plot([x[i],xnew[i]],[y[i],ynew[i]], c='r', lw=1)


xx = r*np.cos(theta)
yy = r*np.sin(-theta)
xxnew= xx*1/l*(l+2*np.pi*(a*.5)) # get the x  for the line extendeaccros the turn
yynew= yy*1/l*(l+2*np.pi*(a*.5)) # get the y  for the line extendeaccros the turn
plt.plot(x, y, c='b', lw=1)
plt.plot(xComp, yComp,c='g', lw=1)



plt.text(0,4.75,'Saros Dial', 
         {'fontname': 'Herculanum',
        'fontsize': '30',
        'fontweight' : 'bold',
        'verticalalignment': 'baseline',
        'horizontalalignment': 'center'})

plt.show()

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
fig.savefig('A4_grid_cm.png', dpi=1000)
fig.savefig('tA4_grid_cm.pdf')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# This example fits a4 paper with 4.2 mm margin printers (HP Laserjet Pro 200)

# # figure settings
# figure_width = 20 # cm
# figure_height = 28.7 # cm
# left_right_margin = 1 # cm
# top_bottom_margin = 1 # cm

# # Don't change
# left   = left_right_margin / figure_width # Percentage from height
# bottom = top_bottom_margin / figure_height # Percentage from height
# width  = 1 - left*2
# height = 1 - bottom*2
# cm2inch = 1/2.54 # inch per cm

# # specifying the width and the height of the box in inches
# fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
# ax = fig.add_axes((left, bottom, width, height))

# # limits settings (important)
# # plt.xlim(0, figure_width * width)#(0,0) at left bottom
# # plt.ylim(0, figure_height * height)#(0,0) at left bottom
# plt.xlim(-figure_width * width/2, figure_width * width/2) #centers (0,0)
# plt.ylim(-figure_height * height/2, figure_height * height/2)#centers (0,0)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)

import matplotlib.pyplot as plt
import matplotlib as mpl

# This example fits DIN A4 paper on a HP Laserjet Pro 200 MFP

# figure settings

left_margin = 0.2
right_margin = 0.9
top_margin = 0.6
bottom_margin = 0.6 


left_right_margin = left_margin+right_margin
top_bottom_margin = top_margin+bottom_margin
figure_width = 21-left_right_margin # cm
figure_height = 29.7-top_bottom_margin 

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm
h_corr = 1.017
v_corr = 1.011

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch*h_corr,figure_height*cm2inch*v_corr))

ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
# plt.xlim(0, figure_width * width)#(0,0) at left bottom
# plt.ylim(0, figure_height * height)#(0,0) at left bottom
plt.xlim(-figure_width * width/2, figure_width * width/2) #centers (0,0)
plt.ylim(-figure_height * height/2, figure_height * height/2)#centers (0,0)

# your Plot (consider above limits)
# # define parameters
a = .03538 # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = 26*np.pi, 34*np.pi # Dial starts at the 13th turn and finishes at the 17th turn
steps = 223+1 # Number of Saros periods (+1 for end marker)


# Generate plotting values
# Main spiral

theta = np.linspace(thetaMin, thetaMax, steps)

r = theta * a

x = r*np.cos(theta)
y = r*np.sin(-theta)

# Main spiral outer rim completion
thetaMinComp, thetaMaxComp = thetaMax, thetaMax+(2*np.pi)

thetaComp= np.linspace(thetaMinComp, thetaMaxComp,steps)


rComp = thetaComp * a

xComp = rComp*np.cos(thetaComp)
yComp = rComp*np.sin(-thetaComp)

# Seperator lines 
# Need to plot between the period startpoint accros the turn(out from the center (0,0))
l=np.sqrt(np.square(x)+np.square(y)+1.2) # calculate length from center, just shortening it makes it not overshoot
xnew= x*1/l*(l+2*np.pi*a) # get the x  for the line extendeaccros the turn
ynew= y*1/l*(l+2*np.pi*a) # get the y  for the line extendeaccros the turn


for i in range(len(x)):
    plt.plot([x[i],xnew[i]],[y[i],ynew[i]], c='r', lw=1)


xx = r*np.cos(theta)
yy = r*np.sin(-theta)
xxnew= xx*1/l*(l+2*np.pi*(a*.5)) # get the x  for the line extendeaccros the turn
yynew= yy*1/l*(l+2*np.pi*(a*.5)) # get the y  for the line extendeaccros the turn
plt.plot(x, y, c='b', lw=1)
plt.plot(xComp, yComp,c='g', lw=1)



plt.text(0,4.75,'Saros Dial', 
         {'fontname': 'Herculanum',
        'fontsize': '30',
        'fontweight' : 'bold',
        'verticalalignment': 'baseline',
        'horizontalalignment': 'center'})

plt.show()

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
fig.savefig('A4_grid_cm.png', dpi=1000)
fig.savefig('tA4_grid_cm.pdf')

# %%
temp=[31,59,90,120,151,181,212,243,273,304,334,365,396,424,455,485,516,546,577,608,638,669,699,730,761,789,820,850,881,911,942,973,1003,1034,1064,1095,1126,1155,1186,1216,1247,1277,1308,1339,1369,1400,1430]

monthstart = [x+1 for x in temp]
monthstart.insert(0,0)
# monthstart

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle, Wedge, Polygon


# # This example fits a4 paper with 4.2mm margin printers

# figure settings
figure_width = 20 # cm
figure_height = 28.7 # cm
left_right_margin = .84 # cm
top_bottom_margin = .84 # cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm


# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
# limits settings (important)
# plt.xlim(0, figure_width * width) #for 0 in left bottom corner 
# plt.ylim(0, figure_height * height) #for 0 in left bottom corner 
# plt.xlim(-figure_width * width/2, figure_width * width/2) #for centered 0
# plt.ylim(-figure_height * height/2, figure_height * height/2) #for centered 0
plt.xlim(-figure_width * width/2, figure_width * width/2) #for centered for LEGO template
plt.ylim((-figure_height * height/2)-3, (figure_height * height/2)-3) #or centered for LEGO template
# Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

#---
import matplotlib.pyplot as plt
import matplotlib as mpl

# This example fits DIN A4 paper on a HP Laserjet Pro 200 MFP

# figure settings

left_margin = 0.2
right_margin = 0.9
top_margin = 0.6
bottom_margin = 0.6 


left_right_margin = left_margin+right_margin
top_bottom_margin = top_margin+bottom_margin
figure_width = 21-left_right_margin # cm
figure_height = 29.7-top_bottom_margin 

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm
h_corr = 1.017
v_corr = 1.011

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch*h_corr,figure_height*cm2inch*v_corr))

ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
# plt.xlim(0, figure_width * width)#(0,0) at left bottom
# plt.ylim(0, figure_height * height)#(0,0) at left bottom
# plt.xlim(-figure_width * width/2, figure_width * width/2) #centers (0,0)
# plt.ylim(-figure_height * height/2, figure_height * height/2)#centers (0,0)
plt.xlim(-figure_width * width/2, figure_width * width/2) #for centered for LEGO template
plt.ylim((-figure_height * height/2)-3, (figure_height * height/2)-3) #or centered for LEGO template
# Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)

temp=[31,59,90,120,151,181,212,243,273,304,334,365,
      396,424,455,485,516,546,577,608,638,669,699,
      730,761,789,820,850,881,911,942,973,1003,1034,
      1064,1095,1126,1155,1186,1216,1247,1277,1308,
      1339,1369,1400,1430]

monthstart = [x+1 for x in temp]
monthstart.insert(0,0)

# ----------------------------------------------------------------------------------------
# define parameters
w=19 #width of main spiral in centimeters
a = w/(72*np.pi)
a = a # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = 26*np.pi, 34*np.pi # Dial starts at the 13th turn and finishes at the 17th turn
steps = 365*4+1+1 # Number of Saros periods (+1 for leapyear,+1 for end marker)


# Generate plotting values
theta = np.linspace(thetaMin, thetaMax, steps)

r = theta * a

x = r*np.cos(theta)
y = r*np.sin(-theta)

# Main spiral outer rim completion
thetaMinComp, thetaMaxComp = thetaMax, thetaMax+(2*np.pi)

thetaComp= np.linspace(thetaMinComp, thetaMaxComp,steps)

rComp = thetaComp * a

xComp = rComp*np.cos(thetaComp)
yComp = rComp*np.sin(-thetaComp)


# Need to plot between the period startpoint accros the turn(out from the center (0,0))
l=np.sqrt(np.square(x)+np.square(y)) # calculate length from center
#day markers
xnew= x*1/l*(l+(2*np.pi)*(0.3/w)) # get the x  for the line extended accros the turn
ynew= y*1/l*(l+(2*np.pi)*(0.3/w)) # get the y  for the line extended accros the turn
#week markers
x2new= x*1/l*(l+1*np.pi*(.9/w)) # get the x  for the line extended accros the turn
y2new= y*1/l*(l+1*np.pi*(.9/w)) # get the y  for the line extended accros the turn
#month markers
x3new= x*1/l*(l+1*np.pi*(1.3/w)) # get the x  for the line extendeaccros the turn
y3new= y*1/l*(l+1*np.pi*(1.3/w)) # get the y  for the line extendeaccros the turn

#start plotting

ax.set_aspect('equal')


for i in range(0,len(x)):
    plt.plot([x[i],xnew[i]],[y[i],ynew[i]], c='r', lw=.75)

for i in range(1,len(x),7):
    plt.plot([x[i],x2new[i]],[y[i],y2new[i]], c='r', lw=1)
    
for i in monthstart:
    plt.plot([x[i],x3new[i]],[y[i],y3new[i]], c='r', lw=1.5)

plt.scatter(0,0)

plt.text(0,3,'Calendar Dial', {'fontname': 'Herculanum',
                               'fontsize': '30',
                               'fontweight' : 'bold',
                               'verticalalignment': 'center',
                               'horizontalalignment': 'center'})

a = a # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = np.pi/12, 2*np.pi+np.pi/12# Dial starts at the 13th turn and finishes at the 17th turn
steps = 13 # Number of Saros periods (+1 for end marker)


# # Generate plotting values

theta = np.linspace(thetaMin, thetaMax, steps)

r = 76*a

x = r*np.cos(-theta)
y = r*np.sin(-theta)
months=['January','February', 'March', 'April','May', 'June', 
        'July', 'August', 'September', 'October','November', 'December']

for label, x, y, angle in zip(months, x, y, np.rad2deg(theta)):
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = angle, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                          'fontsize': '15',
                          'fontweight' : 'bold'})
plt.text(50*a,0,'1 January 2000',fontdict={'fontname': 'Herculanum',
                         'fontsize': '8', 'va': 'center'} )
 # Draw calibration point
radius = 76*a
x_ = (radius*1.05)*np.cos(thetaMin)
y_ = (radius)*np.sin(thetaMin)
plt.scatter(x_,0, marker='>', c='magenta')    

radius = 84*a
x_ = (radius)*np.cos(-(2*np.pi)*(359/365))
y_ = (radius)*np.sin(-(2*np.pi)*(359/365))
plt.scatter(x_,y_, marker='.', c='Green')    

radius = 50*a
x_ = (radius)*np.cos(-(2*np.pi)*(359/365))
y_ = (radius)*np.sin(-(2*np.pi)*(359/365))
plt.scatter(x_,y_, marker='.', c='Green')    


# ----------------------------------------------------------------------------------------
w=19 #width of main spiral in centimeters
patches=[]
ws=[]
we=[]
n = 4
radius = 1.9
for i in np.arange(0,n+1):
    ws.append(360/n*i),
    we.append(360/n*(i+1))
for x in zip(ws,we):
    wedge = Wedge((3*.8-.02, -5*.8-.02), radius, x[0], x[1],width=0.90*radius)
    patches.append(wedge)

colors = np.linspace(0, 1, len(patches[:-1]))
collection = PatchCollection(patches, cmap='brg', alpha=0.3, lw=.2, ec='k')
collection.set_array(colors)
ax.add_collection(collection)


steps = n+1 # (+1 for end marker)
# 
if n%2==0: 
    thetaMin, thetaMax = (0+(2*np.pi/n/2)), (2*np.pi+(2*np.pi/n/2))
if n%2 !=0:
    thetaMin, thetaMax = 0, 2*np.pi
    thetaMin, thetaMax = ((0.5*np.pi)+((2*np.pi)/(.5*steps))), ((2.5*np.pi)+((2*np.pi)/(.5*steps)))

theta = np.linspace(thetaMin, thetaMax, steps)

rOuter = radius*.75 #- to get start value of label correct, also reverse order below

xOuter = rOuter*np.cos(theta)
yOuter = rOuter*np.sin(theta)
    
labels=['1','2','3','4\nL.Y']

for label, x, y, angle in zip(labels[::-1], xOuter+(3*.8), yOuter-(5*.8), np.rad2deg(theta)):
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = 0, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                         'fontsize': '20',
                          'fontweight' : 'black'})
#         plt.scatter(x,y)
plt.text(3*.8, -2*.8,'Spiral\n(from inside)', 
         {'fontname': 'Herculanum',
          'fontsize': '10',
          'fontweight' : 'heavy',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'})

# Draw calibration point
x_ = (radius*1.05)*np.cos(0)+(3*.8)
y_ = (radius*1.05)*np.sin(0)-(5*.8)
plt.scatter(x_,y_, marker='<', c='magenta')
# ----------------------------------------------------------------------------------------

patches=[]
ws=[]
we=[]
n = 15
radius = 2.2
for i in np.arange(0,n+1):
    ws.append(360/n*i),
    we.append(360/n*(i+1))
for x in zip(ws,we):
    wedge = Wedge((-3*.8, -15*.8), radius, x[0], x[1],width=0.90*radius)
    patches.append(wedge)

colors = np.linspace(0, 1, len(patches[:-1]))
collection = PatchCollection(patches, cmap='rainbow', alpha=0.3, lw=.2, ec='k')
collection.set_array(colors)
ax.add_collection(collection)

steps = n+1 # Number of Saros periods (+1 for end marker)

if n%2==0: 
    thetaMin, thetaMax = (0+(2*np.pi/n/2)), (2*np.pi+(2*np.pi/n/2))
if n%2 !=0:
    thetaMin, thetaMax = (0.5*np.pi+(2*np.pi)/(.5*steps)), (2.5*np.pi+(2*np.pi)/(.5*steps))


theta = np.linspace(thetaMin, thetaMax, steps)

rOuter = radius*.8

xOuter = rOuter*np.cos(theta)
yOuter = rOuter*np.sin(theta)
    

labels=[]
for i in range(n):
    labels.append(str(i))
# for label, x, y, angle in zip(labels[::-1], xOuter-3*.8, yOuter-17*.8, np.rad2deg(theta)):
for label, x, y, angle in zip((labels[-6::-1] + labels[:9:-1]), xOuter-3*.8, yOuter-15*.8, np.rad2deg(theta)):
    
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = 0, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                         'fontsize': '15',
                          'fontweight' : 'black'})
#         plt.scatter(x,y)
plt.text(-3*.8,-14.4,'Decades', {'fontname': 'Herculanum',
                                 'fontsize': '15',
                                 'fontweight' : 'heavy',
                                 'verticalalignment': 'center',
                                 'horizontalalignment': 'center'})
                                 
# Draw calibration point
x_ = (radius*1.05)*np.cos(0)-(3*.8)
y_ = (radius*1.05)*np.sin(0)-(15*.8)
plt.scatter(x_,y_, marker='<', c='magenta')

# ----------------------------------------------------------------------------------------
# define parameters
patches=[]
ws=[]
we=[]
n = 10
radius = 2.2
for i in np.arange(0,n+1):
    ws.append(360/n*i),
    we.append(360/n*(i+1))
for x in zip(ws,we):
    wedge = Wedge((3*.8, -15*.8), radius, x[0], x[1],width=0.90*radius)
    patches.append(wedge)

colors = np.linspace(0, 1, len(patches[:-1]))
collection = PatchCollection(patches, cmap='rainbow', alpha=0.3, lw=.2, ec='k')
collection.set_array(colors)
ax.add_collection(collection)

steps = n+1 # Number of Saros periods (+1 for end marker)
 
if n%2==0: 
    thetaMin, thetaMax = (0+(2*np.pi/n/2)), (2*np.pi+(2*np.pi/n/2))
if n%2 !=0:

    thetaMin, thetaMax = (0.5*np.pi+(2*np.pi)/(.5*steps+.5)), (2.5*np.pi+(2*np.pi)/(.5*steps+.5))


theta = np.linspace(thetaMin, thetaMax, steps)

rOuter = radius*.8

xOuter = rOuter*np.cos(theta)
yOuter = rOuter*np.sin(theta)
    

labels=[]
for i in range(n):
    labels.append(str(i))
# for label, x, y, angle in zip(labels[::-1], xOuter+3*.8, yOuter-15*.8, np.rad2deg(theta)):
for label, x, y, angle in zip((labels[-10::-1] + labels[:0:-1]), xOuter+3*.8, yOuter-15*.8, np.rad2deg(theta)):
    
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = 0, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                          'fontsize': '15',
                          'fontweight' : 'black'})
#         plt.scatter(x,y)
plt.text(3*.8,-14.4,'years', {'fontname': 'Herculanum',
                              'fontsize': '15',
                              'fontweight' : 'heavy',
                              'verticalalignment': 'center',
                              'horizontalalignment': 'center'})
                              
# Draw calibration point
x_ = (radius*1.05)*np.cos(0)+(3*.8)
y_ = (radius*1.05)*np.sin(0)-(15*.8)
plt.scatter(x_,y_, marker='<',c='magenta')

# ----------------------------------------------------------------------------------------
#Lego Antikythera attachmetn 'holes'
ax.add_patch(plt.Circle((-9*.8,11*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((9*.8,11*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((-7*.8,0), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((7*.8,0), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((-11*.8,-15*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((11*.8,-15*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Rectangle((-1.5*.8,-1.5*.8), 5*.8, 3*.8, fill=None, ec='grey', lw=.5, zorder=90))
ax.scatter(0,0)
# ----------------------------------------------------------------------------------------

# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)
#1. Remove spines
for spine in plt.gca().spines.values():
    spine.set_visible(False)
#2. Remove ticks
plt.xticks([])
plt.yticks([])

text = 'To calibrate: 1. Set calendar dials to 1 jan 2000 2. Advance mechanism to 25 dec 2000 3. Set moon and saros dials'
plt.text(0,-16,text, {'fontname': 'Herculanum',
                              'fontsize': '8',
                              'fontweight' : 'heavy',
                              'verticalalignment': 'center',
                              'horizontalalignment': 'center'})

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('A4_grid_cm.png', dpi=1000)
fig.savefig('tA4_grid_cm.pdf')

# %%
theta
# Out:
# array([0.78539816, 2.35619449, 3.92699082, 5.49778714, 7.06858347])

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle, Wedge, Polygon

# This example fits a4 paper with 4.2mm margin printers

# figure settings
figure_width = 20 # cm
figure_height = 28.7 # cm
left_right_margin = .84 # cm
top_bottom_margin = .84 # cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm


# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
# limits settings (important)
# plt.xlim(0, figure_width * width) #for 0 in left bottom corner 
# plt.ylim(0, figure_height * height) #for 0 in left bottom corner 
# plt.xlim(-figure_width * width/2, figure_width * width/2) #for centered 0
# plt.ylim(-figure_height * height/2, figure_height * height/2) #for centered 0
plt.xlim(-figure_width * width/2, figure_width * width/2) #for centered for LEGO template
plt.ylim((-figure_height * height/2)-3, (figure_height * height/2)-3) #or centered for LEGO template
# Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)


#------------------------------------                        
w=19 #width of main spiral in centimeters
a = w/(74*np.pi)
a = a # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = 26*np.pi, 34*np.pi # Dial starts at the 13th turn and finishes at the 17th turn
steps = 223+1 # Number of Saros periods (+1 for end marker)

sl =[]
for x in range(223):
    sl.append('')

sl[0]='S18\nM20'
sl[6]='S12\nM15'
sl[12]='S21'
sl[19]='00'
sl[24]='S08'
sl[29]='M04'
sl[30]='S04'
sl[35]='M01'
sl[36]='S23'
sl[41]='S14\nM21'
sl[47]='S03\nM03'
sl[53]='S21'
sl[59]='S11\nM12'
sl[64]='M15'
sl[65]='S03'
sl[70]='M12'
sl[71]='M21'
sl[76]='S15\nM16'
sl[77]='S19'
sl[82]='s04\nM03'
sl[88]='M20'
sl[94]='M13'
sl[100]='M08'
sl[105]='M03'
sl[106]='S17\nM15'
sl[111]='S14\nM13'
sl[117]='M03'
sl[123]='S02\nM02'
sl[124]='S02'
sl[129]='S12'
sl[135]='S08\nM08'
sl[141]='S15\nM03'
sl[147]='M07'
sl[152]='M13'
sl[153]='S14\nM21'
sl[158]='M17'
sl[164]='M20'
sl[170]='S04\nM04'
sl[171]='S15'
sl[176]='S03\nM04'
sl[182]='M20'
sl[188]='S19\nM04'
sl[194]='M12'
sl[199]='M18'
sl[205]='M10'
sl[206]='M10'
sl[211]='M07'
sl[217]='M11'
sl[218]='S10'


# Generate plotting values
# Main spiral

theta = np.linspace(thetaMin, thetaMax, steps)

r = theta * a

x = r*np.cos(theta)
y = r*np.sin(-theta)

# Main spiral outer rim completion
thetaMinComp, thetaMaxComp = thetaMax, thetaMax+(2*np.pi)

thetaComp= np.linspace(thetaMinComp, thetaMaxComp,steps)


rComp = thetaComp * a

xComp = rComp*np.cos(thetaComp)
yComp = rComp*np.sin(-thetaComp)

# Seperator lines 
# Need to plot between the period startpoint accros the turn(out from the center (0,0))
l=np.sqrt(np.square(x)+np.square(y)+10) # calculate length from center, just shortening it makes it not overshoot
xnew= x*1/l*(l+2*np.pi*a) # get the x  for the line extendeaccros the turn
ynew= y*1/l*(l+2*np.pi*a) # get the y  for the line extendeaccros the turn

#start plotting
# fig, ax = plt.subplots(figsize=(20,20))
# # ax.set_aspect('equal')
# plt.axis('off')

for i in range(len(x)):
    plt.plot([x[i],xnew[i]],[y[i],ynew[i]], c='r')
#     plt.scatter(x[i], y[i], c = 'g') # Plots dial points for reference

steps = 223+1 # Number of Saros periods (+1 for end marker)
a = a # determines the width of the turns - set to 1 means width is 2 Pi
thetaMin, thetaMax = (26*np.pi+(2*np.pi)/(.5*steps)), (34*np.pi+(2*np.pi)/(.5*steps)) # Dial starts at the 13th turn and finishes at the 17th turn


theta = np.linspace(thetaMin, thetaMax, steps)

r = theta * a

xx = r*np.cos(theta)
yy = r*np.sin(-theta)
xxnew= xx*1/l*(l+2*np.pi*(a*.5)) # get the x  for the line extendeaccros the turn
yynew= yy*1/l*(l+2*np.pi*(a*.5)) # get the y  for the line extendeaccros the turn
plt.plot(x, y, c='r')
plt.plot(xComp, yComp,c='r')
# plt.scatter(x,y)
# plt.scatter(xxnew,yynew)

for label, x, y, angle in zip(sl, xxnew, yynew, np.rad2deg(theta)):
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = angle, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                         'fontsize': '10',
        'fontweight' : 'bold'})

plt.scatter(0,0)

plt.text(0,3,'Saros Dial', {'fontname': 'Herculanum',
                         'fontsize': '60',
        'fontweight' : 'bold',
        'verticalalignment': 'baseline',
        'horizontalalignment': 'center'})
 # Draw calibration point
radius = 76*a
x_ = (radius*1.05)*np.cos(thetaMin)
y_ = (radius)*np.sin(thetaMin)
plt.scatter(x_,0, marker='.', c='green')    



# ----------------------------------------------------------------------------------------
patches=[]
ws=[]
we=[]
n = 3
radius = 1.9
for i in np.arange(0,n+1):
    ws.append(360/n*i),
    we.append(360/n*(i+1))
for x in zip(ws,we):
    wedge = Wedge((-3*.8,-5*.8), radius, x[0], x[1],width=0.9*radius)
    patches.append(wedge)

colors = np.linspace(0, 1, len(patches[:-1]))
collection = PatchCollection(patches, cmap='brg', alpha=0.15, lw=.2, ec='k')
collection.set_array(colors)
ax.add_collection(collection)


a = 1.9

steps = n+1 #  (+1 for end marker)
#
if n%2==0: 
    thetaMin, thetaMax = (0+(2*np.pi/n/2)), (2*np.pi+(2*np.pi/n/2))
if n%2 !=0:
    thetaMin, thetaMax = 0, 2*np.pi


theta = np.linspace(thetaMin, thetaMax, steps)

rOuter = -a*.6

xOuter = rOuter*np.cos(theta)
yOuter = rOuter*np.sin(theta)
    
labels=['+8 hrs', 'No\nAdjust', '+16 hrs']
# for i in range(n):
#     labels.append(str(i))
for label, x, y, angle in zip(labels, xOuter-3*.8, yOuter-5*.8, np.rad2deg(theta)):
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = 0, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                          'fontsize': '12',
                          'fontweight' : 'black'})
#         plt.scatter(x,y)
        
plt.text(-3*.8,-2*.8,'Time Adjust', {'fontname': 'Herculanum',
                         'fontsize': '10',
        'fontweight' : 'heavy',
        'verticalalignment': 'baseline',
        'horizontalalignment': 'center'})
# Draw calibration point
x_ = (radius*1.05)*np.cos(0)-(3*.8)
y_ = (radius*1.05)*np.sin(0)-(5*.8)
plt.scatter(x_,y_, marker='.',c='green')



# ---------------------------------------------------------------------------------------
patches=[]
ws=[]
we=[]
n = 4
radius = 1.9
for i in np.arange(0,n+1):
    ws.append(360/n*i),
    we.append(360/n*(i+1))
for x in zip(ws,we):
    wedge = Wedge((3*.8,-5*.8), radius, x[0], x[1],width=0.90*radius)
    patches.append(wedge)

colors = np.linspace(0, 1, len(patches[:-1]))
collection = PatchCollection(patches, cmap='brg', alpha=0.15, lw=.2, ec='k')
collection.set_array(colors)
ax.add_collection(collection)


a = radius

steps = n+1 # Number of Saros periods (+1 for end marker)

if n%2==0: 
    thetaMin, thetaMax = (0+(2*np.pi/n/2)), (2*np.pi+(2*np.pi/n/2))
if n%2 !=0:
    thetaMin, thetaMax = 0, 2*np.pi


theta = np.linspace(thetaMin, thetaMax, steps)

rOuter = a*.6

xOuter = rOuter*np.cos(theta)
yOuter = rOuter*np.sin(theta)
    

labels=[]
for i in range(n):
    labels.append(str(i+1))
for label, x, y, angle in zip(labels[::-1], xOuter+3*.8, yOuter-5*.8, np.rad2deg(theta)):
        if y < 0: angle = -angle+90 
        if y > 0: angle = -angle-90
        plt.text(x,y, label , rotation = 0, ha="center", va="center",
                fontdict={'fontname': 'Herculanum',
                         'fontsize': '20',
        'fontweight' : 'black'})
#         plt.scatter(x,y)
plt.text(3*.8,-2*.8,'Spiral\n(from inside)', {'fontname': 'Herculanum',
                         'fontsize': '10',
        'fontweight' : 'heavy',
        'verticalalignment': 'baseline',
        'horizontalalignment': 'center'})
# Draw calibration point
x_ = (radius*1.05)*np.cos(0)+(3*.8)
y_ = (radius*1.05)*np.sin(0)-(5*.8)
plt.scatter(x_,y_, marker='.',c='green')

# ----------------------------------------------------------------------------------------
ax.add_patch(plt.Circle((-9*.8,11*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((9*.8,11*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((-7*.8,0), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((7*.8,0), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((-11*.8,-15*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))
ax.add_patch(plt.Circle((11*.8,-15*.8), .48/2, fill=None, ec='grey', lw=.5, zorder=90))

ax.scatter(0,0)
# ----------------------------------------------------------------------------------------

# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)
#1. Remove spines
for spine in plt.gca().spines.values():
    spine.set_visible(False)
#2. Remove ticks
plt.xticks([])
plt.yticks([])



# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('A4_grid_cm.png', dpi=1000)
fig.savefig('tA4_grid_cm.pdf')
